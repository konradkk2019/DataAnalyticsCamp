# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
location = "Kickstartercombo.csv"

df = pd.read_csv(location)
df.head()
# Out:
#    Unnamed: 0          ID                                               name  \
# 0           0  1000002330                    The Songs of Adelaide & Abullah
# 1           1  1000004038                                     Where is Hank?
# 2           2  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 3           3  1000011046  Community Film Project: The Art of Neighborhoo...
# 4           4  1000014025                               Monarch Espresso Bar
#
#   main_category        category country       state     goal  pledged  \
# 0    Publishing          Poetry      GB      failed   1000.0      0.0
# 1  Film & Video  Narrative Film      US      failed  45000.0    220.0
# 2         Music           Music      US      failed   5000.0      1.0
# 3  Film & Video    Film & Video      US    canceled  19500.0   1283.0
# 4          Food     Restaurants      US  successful  50000.0  52375.0
#
#   currency             launched             deadline  backers  usd pledged  \
# ...

# %%
#drops duplicate rows, default is to keep first observation
nodupedf = df.drop_duplicates()
nodupedf.count()
# Out:
# Unnamed: 0          702411
# ID                  702411
# name                702403
# main_category       702411
# category            702411
# country             702411
# state               702411
# goal                702411
# pledged             702411
# currency            702411
# launched            702411
# deadline            702411
# backers             702411
# usd pledged         694817
# usd_goal_real       378661
# usd_pledged_real    378661
# dtype: int64

# %%
#There is not duplicated values
dupe = df.duplicated()

# %%
df.count()
# Out:
# Unnamed: 0          702411
# ID                  702411
# name                702403
# main_category       702411
# category            702411
# country             702411
# state               702411
# goal                702411
# pledged             702411
# currency            702411
# launched            702411
# deadline            702411
# backers             702411
# usd pledged         694817
# usd_goal_real       378661
# usd_pledged_real    378661
# dtype: int64

# %% [markdown]
# Clening up out data

# %%
#Identify projcts with Zero backers
dfBackersZero = df[ df['backers'] == 0 ]

# %%
dfBackersZero
# Out:
#         Unnamed: 0          ID  \
# 0                0  1000002330
# 9                9   100004721
# 11              11  1000055792
# 12              12  1000056157
# 23              23  1000103948
# 38              38  1000182258
# 48              48  1000226576
# 57              57  1000245024
# 65              65  1000282287
# 67              67  1000291263
# 89              89  1000399155
# 101            101  1000476123
# 106            106  1000509854
# 108            108   100051531
# 110            110  1000521061
# 114            114  1000537760
# 128            128  1000581804
# 132            132  1000600526
# 146            146  1000659557
# 150            150  1000694855
# 158            158  1000727905
# 175            175  1000802137
# 179            179  1000834930
# 183            183  1000865260
# 188            188  1000896053
# 189            189   100091944
# 192            192  1000937140
# 194            194  1000942804
# 198            198  1000988678
# ...

# %%
#We drop all backers with Zero value
df = df.drop(dfBackersZero.index, axis=0)

# %%
dfBackersZero = df[ df['backers'] == 0 ]

# %%
dfBackersZero
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ID, name, main_category, category, country, state, goal, pledged, currency, launched, deadline, backers, usd pledged, usd_goal_real, usd_pledged_real]
# Index: []

# %%
df.describe()
# Out:
#           Unnamed: 0            ID          goal       pledged        backers  \
# count  597837.000000  5.978370e+05  5.978370e+05  5.978370e+05  597837.000000
# mean   351579.341334  1.074014e+09  4.050577e+04  1.079886e+04     121.870505
# std    202764.046891  6.190077e+08  9.929588e+05  1.004438e+05     995.738221
# min         1.000000  5.971000e+03  1.000000e-02  1.000000e+00       1.000000
# 25%    175968.000000  5.371012e+08  2.000000e+03  1.350000e+02       4.000000
# 50%    351896.000000  1.074494e+09  5.300000e+03  1.101000e+03      19.000000
# 75%    527118.000000  1.609535e+09  1.500000e+04  5.165000e+03      69.000000
# max    702410.000000  2.147476e+09  1.000000e+08  2.033899e+07  219382.000000
#
#         usd pledged  usd_goal_real  usd_pledged_real
# count  5.978370e+05   3.230520e+05      3.230520e+05
# mean   8.607325e+03   3.819576e+04      1.058362e+04
# std    8.773950e+04   9.686166e+05      9.829133e+04
# min    0.000000e+00   1.000000e-02      4.500000e-01
# ...

# %%
#New dataframe only with project which has more than Zero backers
df.count()
# Out:
# Unnamed: 0          597837
# ID                  597837
# name                597831
# main_category       597837
# category            597837
# country             597837
# state               597837
# goal                597837
# pledged             597837
# currency            597837
# launched            597837
# deadline            597837
# backers             597837
# usd pledged         597837
# usd_goal_real       323052
# usd_pledged_real    323052
# dtype: int64

# %%
#We filter only projects from US and only those successful
dfUSprojects = df[ (df['country'] == 'US') & (df['state'] == 'successful')]
dfUSprojects
# Out:
#         Unnamed: 0          ID  \
# 4                4  1000014025
# 5                5  1000023410
# 10              10   100005484
# 16              16  1000070642
# 18              18  1000072011
# 21              21  1000091520
# 22              22  1000102741
# 27              27  1000117861
# 30              30   100012079
# 32              32  1000131947
# 33              33  1000132945
# 35              35  1000146991
# 36              36  1000160286
# 37              37  1000171141
# 39              39  1000183112
# 40              40  1000184224
# 41              41  1000190427
# 43              43  1000201265
# 45              45  1000212914
# 46              46  1000216800
# 49              49  1000227361
# 51              51  1000232288
# 55              55  1000235643
# 58              58  1000252415
# 63              63  1000268182
# 68              68  1000294559
# 73              73  1000332383
# 74              74  1000333671
# 75              75  1000334074
# ...

# %%
dfClean=dfUSprojects

# %%
dfClean
# Out:
#         Unnamed: 0          ID  \
# 4                4  1000014025
# 5                5  1000023410
# 10              10   100005484
# 16              16  1000070642
# 18              18  1000072011
# 21              21  1000091520
# 22              22  1000102741
# 27              27  1000117861
# 30              30   100012079
# 32              32  1000131947
# 33              33  1000132945
# 35              35  1000146991
# 36              36  1000160286
# 37              37  1000171141
# 39              39  1000183112
# 40              40  1000184224
# 41              41  1000190427
# 43              43  1000201265
# 45              45  1000212914
# 46              46  1000216800
# 49              49  1000227361
# 51              51  1000232288
# 55              55  1000235643
# 58              58  1000252415
# 63              63  1000268182
# 68              68  1000294559
# 73              73  1000332383
# 74              74  1000333671
# 75              75  1000334074
# ...

# %%
#export csv files

dfClean.to_csv('finalData.csv',index=False,header=True)
