# %%
#import libraries
import pandas as pd
import numpy as np

#load csv file data with headers
location = "diamonds.csv"
df = pd.read_csv(location)

# %%
df.head()
#df.head?
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
#show the number of rows and columns in a dataframe
df.shape
# Out:
# (53940, 11)

# %%
#show the data type of each column
df.dtypes
# Out:
# Unnamed: 0      int64
# carat         float64
# cut            object
# color          object
# clarity        object
# depth         float64
# table         float64
# price           int64
# x             float64
# y             float64
# z             float64
# dtype: object

# %%
#number of non-NA values
#len(df) would count rows including NA values
df.count()
# Out:
# Unnamed: 0    53940
# carat         53940
# cut           53940
# color         53940
# clarity       53940
# depth         53940
# table         53940
# price         53940
# x             53940
# y             53940
# z             53940
# dtype: int64

# %%
#descriptive statistics
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
#doesn't do anything on its own
df.groupby('carat')

# %%
#add a stats or math function to it
df['price'].groupby(df['cut']).mean()
# Out:
# cut
# Fair         4358.757764
# Good         3928.864452
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Name: price, dtype: float64

# %%
df['price'].groupby(df['clarity']).mean()
# Out:
# clarity
# I1      3924.168691
# IF      2864.839106
# SI1     3996.001148
# SI2     5063.028606
# VS1     3839.455391
# VS2     3924.989395
# VVS1    2523.114637
# VVS2    3283.737071
# Name: price, dtype: float64

# %%
#pivot table default function is mean
pd.pivot_table(df, index=['cut'])
# Out:
#              Unnamed: 0     carat      depth        price      table  \
# cut
# Fair       24147.357764  1.046137  64.041677  4358.757764  59.053789
# Good       24774.931309  0.849185  62.365879  3928.864452  58.694639
# Ideal      29047.630736  0.702837  61.709401  3457.541970  55.951668
# Premium    25600.209049  0.891955  61.264673  4584.257704  58.746095
# Very Good  26097.313193  0.806381  61.818275  3981.759891  57.956150
#
#                   x         y         z
# cut
# Fair       6.246894  6.182652  3.982770
# Good       5.838785  5.850744  3.639507
# Ideal      5.507451  5.520080  3.401448
# Premium    5.973887  5.944879  3.647124
# Very Good  5.740696  5.770026  3.559801

# %%
#pivot table default function is mean
pd.pivot_table(df, index=['carat'])
# Out:
#           G      3720.706388
#           H      3889.334831
#           I      4451.970377
#           J      4918.186384
# Premium   D      3631.292576
#           E      3538.914420
#           F      4324.890176
#           G      4500.742134
#           H      5216.706780
#           I      5946.180672
#           J      6294.591584
# Very Good D      3470.467284
#           E      3214.652083
# ...

# %%
#still using gradedata.csv
#df.head() if needed

df.sort_values('price') #default is ascending=True
#does not change structure of df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5               6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6               7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7               8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8               9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9              10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
# 10             11   0.30       Good     J     SI1   64.0   55.0    339  4.25
# ...

# %%
#pivot table default function is mean
pd.pivot_table(df, index=['clarity'])
# Out:
#            Unnamed: 0     carat      depth        price      table         x  \
# clarity
# I1       22419.002699  1.283846  62.734278  3924.168691  58.303779  6.761093
# IF       33591.562011  0.505123  61.510615  2864.839106  56.507207  4.968402
# SI1      25585.839112  0.850482  61.853042  3996.001148  57.662541  5.888383
# SI2      21453.988580  1.077648  61.772167  5063.028606  57.927181  6.401370
# VS1      27933.116510  0.727158  61.667458  3839.455391  57.315151  5.572178
# VS2      27831.973405  0.763935  61.724417  3924.989395  57.417401  5.657709
# VVS1     32402.172093  0.503321  61.624651  2523.114637  56.884460  4.960364
# VVS2     31323.464272  0.596202  61.663778  3283.737071  57.024990  5.218454
#
#                 y         z
# clarity
# I1       6.709379  4.207908
# IF       4.989827  3.061659
# SI1      5.888256  3.639845
# SI2      6.397826  3.948478
# VS1      5.581828  3.441007
# VS2      5.658859  3.491478
# VVS1     4.975075  3.061294
# ...

# %%
#pivot table default function is mean
pd.pivot_table(df, index=['table'])
# Out:
#          Unnamed: 0     carat      depth         price         x         y  \
# table
# 43.0   11369.000000  1.040000  62.900000   4997.000000  6.450000  6.410000
# 44.0   35634.000000  0.290000  62.800000    474.000000  4.200000  4.240000
# 49.0   14341.000000  0.650000  64.250000   2290.500000  5.355000  5.320000
# 50.0   16299.500000  1.510000  61.500000   8995.500000  7.380000  7.295000
# 50.1    3239.000000  0.940000  66.000000   3353.000000  6.130000  6.170000
# 51.0   24216.333333  0.883333  63.300000   4063.666667  5.995556  5.941111
# 51.6   24816.000000  2.000000  61.000000  13203.000000  8.140000  8.180000
# 52.0   27846.267857  0.871071  62.833929   4342.000000  5.877143  5.870179
# 52.4   45496.000000  0.500000  62.500000   1679.000000  5.070000  5.110000
# ...

# %%
#pivot table default function is mean
pd.pivot_table(df, index=['z'])
# Out:
#          Unnamed: 0     carat      depth         price      table          x  \
# z
# 0.00   21967.450000  1.449000  61.455000   8803.100000  58.400000   4.465000
# 1.07   14636.000000  1.070000  60.600000   5909.000000  57.000000   6.620000
# 1.41   21655.000000  1.410000  60.700000   9752.000000  56.000000   7.310000
# 1.53   20695.000000  1.530000  61.900000   8971.000000  54.000000   7.430000
# 2.06   39247.000000  0.380000  60.900000   1068.000000  56.000000   4.710000
# 2.24   31593.000000  0.200000  59.000000    367.000000  60.000000   3.810000
# 2.25   47139.000000  0.550000  61.000000   1831.000000  59.000000   5.310000
# 2.26   31592.000000  0.200000  59.800000    367.000000  62.000000   3.790000
# 2.27      15.000000  0.200000  60.200000    345.000000  62.000000   3.790000
# 2.28   31595.000000  0.200000  59.700000    367.000000  62.000000   3.840000
# 2.29   38279.000000  0.210000  59.100000    386.000000  62.000000   3.890000
# ...

# %%
#pivot table default function is mean
pd.pivot_table(df, index=['carat'])
# Out:
#          Unnamed: 0      depth         price      table          x          y  \
# carat
# 0.20   28965.166667  61.100000    365.166667  59.333333   3.786667   3.753333
# 0.21   34659.000000  60.511111    380.222222  58.444444   3.874444   3.837778
# 0.22    6948.600000  61.620000    391.400000  60.400000   3.898000   3.848000
# 0.23   35756.993174  61.426621    486.143345  58.034130   3.946382   3.973379
# 0.24   31885.330709  61.599213    505.185039  57.488189   3.990157   4.019331
# 0.25   27251.905660  61.565566    550.924528  57.363208   4.062500   4.086934
# 0.26   25794.683794  61.677470    550.897233  56.911858   4.102688   4.124704
# 0.27   26385.497854  61.599142    574.759657  56.778970   4.159142   4.181588
# 0.28   29973.500000  61.526263    580.121212  56.863636   4.207172   4.233687
# 0.29   29105.807692  61.393077    601.192308  56.846154   4.262846   4.290538
# 0.30   31137.293779  61.914631    680.301843  57.134217   4.299443   4.308061
# ...

# %%
#Standard Deviation Method

meangrade = df['grade'].mean()
stdgrade = df['grade'].std()
toprange = meangrade + stdgrade * 1.96
botrange = meangrade - stdgrade * 1.96

newdf = df.copy() #to not mess up the original df
newdf = newdf.drop(newdf[newdf['grade'] > toprange].index)
newdf = newdf.drop(newdf[newdf['grade'] < botrange].index)

newdf.head()

# %%
df.corr()
# Out:
#             Unnamed: 0     carat     depth     table     price         x  \
# Unnamed: 0    1.000000 -0.377983 -0.034800 -0.100830 -0.306873 -0.405440
# carat        -0.377983  1.000000  0.028224  0.181618  0.921591  0.975094
# depth        -0.034800  0.028224  1.000000 -0.295779 -0.010647 -0.025289
# table        -0.100830  0.181618 -0.295779  1.000000  0.127134  0.195344
# price        -0.306873  0.921591 -0.010647  0.127134  1.000000  0.884435
# x            -0.405440  0.975094 -0.025289  0.195344  0.884435  1.000000
# y            -0.395843  0.951722 -0.029341  0.183760  0.865421  0.974701
# z            -0.399208  0.953387  0.094924  0.150929  0.861249  0.970772
#
#                    y         z
# Unnamed: 0 -0.395843 -0.399208
# carat       0.951722  0.953387
# depth      -0.029341  0.094924
# table       0.183760  0.150929
# price       0.865421  0.861249
# x           0.974701  0.970772
# y           1.000000  0.952006
# z           0.952006  1.000000

# %%
#use this library to build a statistical test for linear regression
import statsmodels.formula.api as smf

# %%
#OLS is Ordinary Least Squares, the most common type of linear regression
#the fit function uses the predictive values to calculate the best linear regression line
result = smf.ols('price ~ cut + color + clarity + carat + x + y + z + depth + table ', data=df).fit()

# %%
#the summary will show the calculated values (slopes and y-intercept) for the linear regression formula
#the closer to 1 the r-squared value is, the better the fit of the linear regression line
#the p-value shows how statistically significant a predictive feature could be the model

result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.920
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                 2.688e+04
# Date:                Wed, 29 May 2019   Prob (F-statistic):               0.00
# Time:                        15:45:20   Log-Likelihood:            -4.5573e+05
# No. Observations:               53940   AIC:                         9.115e+05
# Df Residuals:                   53916   BIC:                         9.117e+05
# Df Model:                          23
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn #library for predictive modeling

# %matplotlib inline
#compare number of rooms to home price
plt.scatter(df['price'], df['carat']) 
plt.xlabel("Price") 
plt.ylabel("Carat") 
plt.title("Relationship between Price and Carat") 
plt.show()

# %%
#compare number of rooms to home price
plt.scatter(df['price'], df['cut']) 
plt.xlabel("Price") 
plt.ylabel("Cut") 
plt.title("Relationship between Price and Cut") 
plt.show()

# %%
#compare number of rooms to home price
plt.scatter(df['price'], df['clarity']) 
plt.xlabel("Price") 
plt.ylabel("Clarity") 
plt.title("Relationship between Price and Clarity") 
plt.show()

# %%
#compare number of rooms to home price
plt.scatter(df['price'], df['color']) 
plt.xlabel("Price") 
plt.ylabel("Color") 
plt.title("Relationship between Price and Color") 
plt.show()

# %%
#compare number of rooms to home price
plt.scatter(df['price'], df['depth']) 
plt.xlabel("Price") 
plt.ylabel("Depth") 
plt.title("Relationship between Price and Depth") 
plt.show()

# %%
#compare number of rooms to home price
plt.scatter(df['price'], df['table']) 
plt.xlabel("Price") 
plt.ylabel("table") 
plt.title("Relationship between Price and table") 
plt.show()

# %%
#compare number of rooms to home price
plt.scatter(df['price'], df['x']) 
plt.xlabel("Price") 
plt.ylabel("x") 
plt.title("Relationship between Price and x") 
plt.show()

# %%
#compare number of rooms to home price
plt.scatter(df['price'], df['y']) 
plt.xlabel("Price") 
plt.ylabel("y") 
plt.title("Relationship between Price and y") 
plt.show()

# %%
#compare number of rooms to home price
plt.scatter(df['price'], df['z']) 
plt.xlabel("Price") 
plt.ylabel("z") 
plt.title("Relationship between Price and z") 
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#create a histogram of the distribution of attack power
sns.distplot(df['price'])

# %%
#create a histogram of the distribution of attack power
sns.distplot(df['carat'])

# %%
sns.distplot(df['depth'])

# %%
sns.distplot(df['table'])

# %%
sns.distplot(df['x'])

# %%
sns.distplot(df['y'])

# %%
sns.distplot(df['z'])
